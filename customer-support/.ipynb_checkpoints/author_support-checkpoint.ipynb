# %%
from typing import TypedDict, Optional
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, END, START
from langgraph.types import interrupt
from langgraph.checkpoint.memory import InMemorySaver

from pydantic import BaseModel
from typing import Literal

from knowledge import documents

# %%
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
from langchain_core.messages import SystemMessage, AIMessage
from langchain_openai import OpenAIEmbeddings

# %%
import sqlite3
from datetime import datetime, date
from dotenv import load_dotenv

load_dotenv()

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
checkpointer = InMemorySaver()
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
class IntentClassification(BaseModel):
    intent: Literal["faq", "query", "complaint"]

# %%
def similarity_search(query):
    # get the info chunks
    chunks = documents

    # Create in-memory vector store (FAISS)
    vector_store = FAISS.from_documents(chunks, embeddings)

    # perform similarity search with score
    results = vector_store.similarity_search_with_score(query, k=1)

    # unpack result
    doc, dist = results[0]
    context = doc.page_content

    return {
        "context": context,
        "distance": float(dist)
    }

# %% [markdown]
# ### Add Tools

# %%
def get_book(book_id):
    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT * FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    book = cursor.fetchone()

    if not book:
        raise ValueError(f"Book with id {book_id} not found")

    return book

# %%
def get_royalty_earned(book_id: int):
    """Get the royalty earnings for a book."""
    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT royality_earned FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    royalty = cursor.fetchone()

    if not royalty:
        raise ValueError(f"Book with id {book_id} not found")

    return royalty

# %%
get_royality_earned(70)
# Out:
# (28,)

# %%
def get_royalty_pending(book_id: int):
    """Get the pending royalty for a book."""

    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT royality_pending FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    royalty = cursor.fetchone()

    if not royalty:
        raise ValueError(f"Book with id {book_id} not found")

    return royalty

# %%
def get_royalty_paid(book_id: int):
    """Get the pending royalty for a book."""

    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT royality_paid FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    royalty = cursor.fetchone()

    if not royalty:
        raise ValueError(f"Book with id {book_id} not found")

    return royalty

# %%
get_royalty_paid(70)
# Out:
# (0,)

# %%
get_royalty_pending(70)
# Out:
# (2464,)

# %%
def get_book_pub_date(book_id: int):
    """Get the current publication status of a book."""

    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT pub_date FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    pub_date = cursor.fetchone()

    if not pub_date:
        raise ValueError(f"Book with id {book_id} not found")

    return pub_date

# %%
get_book_pub_date(70)
# Out:
# ('2024-09-10',)

# %% [markdown]
# ## Tool call

# %%
tools = [
    get_royality_earned,
    get_royality_pending,
    get_royalty_paid,
    get_book_pub_date
]

# %%
llm_with_tools = llm.bind_tools(tools)

# %%
from langgraph.graph import MessagesState

class State(MessagesState):
    book: int

# %%
def start_graph(state: State) -> State:
    return state

# %%
def get_user_intent(state: State) -> Literal["faq", "query", "complaint"]:
    
    intent = input("Pick your choice: faq, query, complaint")
    if not intent in ["faq", "query", "complaint"]:
        raise AssertionError("incorrect intent provide")
    return intent

# %%
def assistant(state: State) -> State:

    book_id = state["book"]

    sys_msg = SystemMessage(
        content=(
            "You are a helpful assistant for BookLeaf Publishing. "
            f"You are assisting the author for book ID: {book_id}. "
            "Use the available tools to retrieve book-specific information."
        )
    )

    llm_response = llm_with_tools.invoke(
        [sys_msg] + state["messages"]
    )

    return {
        "messages": [llm_response]
    }

# %%
def register_complaint(state: State) -> State:

    book_id = state["book"]
    query = state["messages"][-1].content


    response = AIMessage(
        content=(
            "Sorry about that. "
            "Your complaint has been registered and will be reviewed."
        )
    )

    return {
        "messages": [response]
    }

# %%
INFO_PROMPT = f"""Return an appropriate answer in markdown syntax for user query.
"""

# %%
def get_info(state: State) -> State:

    query = state["messages"][-1].content
    book_id = state["book"]

    search_result = similarity_search(query)

    context = search_result["context"]
    distance = search_result["distance"]

    if distance >= 0.8:
        response_context = (
            "The knowledge base does not contain enough "
            "information to confidently answer this question."
        )

    else:
        response_context = context

    prompt = INFO_PROMPT

    prompt += (
        f"\nQuery: {query}"
        f"\nResponse: {response_context}"
    )

    llm_response = llm.invoke(prompt)

    return {
        "messages": [
            AIMessage(content=llm_response.content)
        ]
    }

# %%
def build_graph():
    from langgraph.prebuilt import (
        tools_condition,
        ToolNode,
    )
    builder = StateGraph(State)

    builder.add_node("start_graph", start_graph)

    builder.add_node("get_info", get_info)

    builder.add_node("assistant", assistant)

    builder.add_node("register_complaint", register_complaint)

    builder.add_node("tools", ToolNode(tools))

    builder.add_edge(START, "start_graph")

    # Intent routing
    builder.add_conditional_edges(
        "start_graph",
        get_user_intent,
        {
            "faq": "get_info",
            "query": "assistant",
            "complaint": "register_complaint"
        }
    )

    # Tool routing
    builder.add_conditional_edges(
        "assistant",
        tools_condition,
    )

    builder.add_edge(
        "tools",
        "assistant"
    )

    react_graph = builder.compile(
        checkpointer=checkpointer
    )

    return react_graph

# %%
graph = build_graph()

# %%
graph

# %%
from langchain_core.messages import HumanMessage
s = {
    "book": 70,
    "messages": [HumanMessage(content="Show me my pending royalty")],
    
}
config = {
    "configurable": {
        "thread_id": "101"
    }
}

# %%
result = graph.invoke(s, config=config)
# Out:
# Pick your choice: faq, query, complaint query

# %%
result
# Out:
# {'messages': [HumanMessage(content='Pathetic service, i want to quit', additional_kwargs={}, response_metadata={}, id='1b3206aa-f389-473e-b389-13516c3573ea'),
#   HumanMessage(content='Pathetic service, i want to quit', additional_kwargs={}, response_metadata={}, id='8e7d3e10-4ace-4b3f-8cee-ef69a21b5cc9'),
#   AIMessage(content="```markdown\nI'm sorry to hear that you're experiencing issues with our service. If you would like to quit, please let us know how we can assist you in the process. Your feedback is important to us, and we would appreciate any details you can provide about your experience.\n```", additional_kwargs={}, response_metadata={}, id='635b1779-af87-4f93-99c3-2f1515c21e1e', tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='Show me my pending royalty', additional_kwargs={}, response_metadata={}, id='046c524c-b091-44e3-873f-f1b0be1c91ca'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 249, 'total_tokens': 267, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4f1c1cfc4e', 'id': 'chatcmpl-EPB922UkaMc3mX1uHLwcb0HkLELXS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b0a1-2de2-7982-9bab-434c3562c6e6-0', tool_calls=[{'name': 'get_royality_pending', 'args': {'book_id': 70}, 'id': 'call_oapXGy2N7PzHnVgJtYM0wQNG', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 249, 'output_tokens': 18, 'total_tokens': 267, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[2464]', name='get_royality_pending', id='af48f803-ba8c-4a18-a9dc-e33a74127c3c', tool_call_id='call_oapXGy2N7PzHnVgJtYM0wQNG'),
#   AIMessage(content='Your pending royalty for book ID 70 is $2,464.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 282, 'total_tokens': 297, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4f1c1cfc4e', 'id': 'chatcmpl-EPB93qUsTOq4jfCHhUU48KEzEWgXO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b0a1-34cb-7cd3-bdda-78f31f5ce587-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 282, 'output_tokens': 15, 'total_tokens': 297, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'book': 70}

# %%
from langchain_core.messages import HumanMessage
s = {
    "book": 70,
    "messages": [HumanMessage(content="What is your ISBN policy?")],
    
}
config = {
    "configurable": {
        "thread_id": "101"
    }
}

# %%
result = graph.invoke(s, config=config)
# Out:
# Pick your choice: faq, query, complaint faq

# %%
result
# Out:
# {'messages': [HumanMessage(content='Pathetic service, i want to quit', additional_kwargs={}, response_metadata={}, id='1b3206aa-f389-473e-b389-13516c3573ea'),
#   HumanMessage(content='Pathetic service, i want to quit', additional_kwargs={}, response_metadata={}, id='8e7d3e10-4ace-4b3f-8cee-ef69a21b5cc9'),
#   AIMessage(content="```markdown\nI'm sorry to hear that you're experiencing issues with our service. If you would like to quit, please let us know how we can assist you in the process. Your feedback is important to us, and we would appreciate any details you can provide about your experience.\n```", additional_kwargs={}, response_metadata={}, id='635b1779-af87-4f93-99c3-2f1515c21e1e', tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='Show me my pending royalty', additional_kwargs={}, response_metadata={}, id='046c524c-b091-44e3-873f-f1b0be1c91ca'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 249, 'total_tokens': 267, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4f1c1cfc4e', 'id': 'chatcmpl-EPB922UkaMc3mX1uHLwcb0HkLELXS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b0a1-2de2-7982-9bab-434c3562c6e6-0', tool_calls=[{'name': 'get_royality_pending', 'args': {'book_id': 70}, 'id': 'call_oapXGy2N7PzHnVgJtYM0wQNG', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 249, 'output_tokens': 18, 'total_tokens': 267, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[2464]', name='get_royality_pending', id='af48f803-ba8c-4a18-a9dc-e33a74127c3c', tool_call_id='call_oapXGy2N7PzHnVgJtYM0wQNG'),
#   AIMessage(content='Your pending royalty for book ID 70 is $2,464.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 282, 'total_tokens': 297, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_4f1c1cfc4e', 'id': 'chatcmpl-EPB93qUsTOq4jfCHhUU48KEzEWgXO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b0a1-34cb-7cd3-bdda-78f31f5ce587-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 282, 'output_tokens': 15, 'total_tokens': 297, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='What is your ISBN policy?', additional_kwargs={}, response_metadata={}, id='7831e7b9-78b2-49ff-8be9-8ebb4ac71af3'),
#   AIMessage(content='```markdown\n# ISBN Policy\n\n- Every book published through BookLeaf receives a unique ISBN assigned by BookLeaf.\n- ISBNs are registered under BookLeaf’s publisher imprint. If an author wants an ISBN under their own imprint, they need to obtain it independently.\n- If an author reports an ISBN error (duplicate, wrong book linked), it is treated as a high-priority issue and escalated to the production team.\n```', additional_kwargs={}, response_metadata={}, id='16657483-40f6-466a-9980-1deabffdf385', tool_calls=[], invalid_tool_calls=[])],
#  'book': 70}

# %% [markdown]
# ## Evaluations
