# %% [markdown]
# ## Load dependencies

# %%
from typing import TypedDict, Optional
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, END, START
from langgraph.types import interrupt
from langgraph.checkpoint.memory import InMemorySaver

from pydantic import BaseModel
from typing import Literal

from knowledge import documents
from prompt import INTENT_PROMPT

# %%
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
from langchain_core.messages import SystemMessage, AIMessage, HumanMessage
from langchain_openai import OpenAIEmbeddings

# %% [markdown]
# ## Initialize LLM

# %%
import sqlite3
from datetime import datetime, date
from dotenv import load_dotenv

load_dotenv()

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
checkpointer = InMemorySaver()
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
class IntentClassification(BaseModel):
    intent: Literal["faq", "query", "complaint"]

# %%
def similarity_search(query):
    # get the info chunks
    chunks = documents

    # Create in-memory vector store (FAISS)
    vector_store = FAISS.from_documents(chunks, embeddings)

    # perform similarity search with score
    results = vector_store.similarity_search_with_score(query, k=1)

    # unpack result
    doc, dist = results[0]
    context = doc.page_content

    return {
        "context": context,
        "distance": float(dist)
    }

# %%
from langgraph.graph import MessagesState

class State(MessagesState):
    user_input: str    
    book_id: Optional[int]
    intent: Literal["faq", "query", "complaint"]

# %% [markdown]
# ### Add Tools

# %%
def get_book(book_id):
    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT * FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    book = cursor.fetchone()

    if not book:
        raise ValueError(f"Book with id {book_id} not found")
    conn.close()
    return book

# %%
def get_royalty_earned(book_id: int):
    """Get the royalty earnings for a book."""
    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT royality_earned FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    royalty = cursor.fetchone()

    if not royalty:
        raise ValueError(f"Book with id {book_id} not found")
        
    conn.close()
    return royalty

# %%
get_royalty_earned(70)
# Out:
# (28,)

# %%
def get_royalty_pending(book_id: int):
    """Get the pending royalty for a book."""
    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT royality_pending FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    royalty = cursor.fetchone()

    if not royalty:
        raise ValueError(f"Book with id {book_id} not found")
    conn.close()
    return royalty

# %%
def get_royalty_paid(book_id: int):
    """Get the pending royalty for a book."""

    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT royality_paid FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    royalty = cursor.fetchone()

    if not royalty:
        raise ValueError(f"Book with id {book_id} not found")

    conn.close()
    return royalty

# %%
get_royalty_paid(70)
# Out:
# (0,)

# %%
get_royalty_pending(70)
# Out:
# (2464,)

# %%
def get_book_pub_date(book_id: int):
    """Get the current publication status of a book."""

    conn = sqlite3.connect("db.sqlite3")
    cursor = conn.cursor()
    
    cursor.execute(
    "SELECT pub_date FROM author_book WHERE id = ?",
    (book_id,)
    )
    
    pub_date = cursor.fetchone()

    if not pub_date:
        raise ValueError(f"Book with id {book_id} not found")

    conn.close()
    return pub_date

# %%
get_book_pub_date(70)
# Out:
# ('2024-09-10',)

# %% [markdown]
# ## Tool call

# %%
tools = [
    get_royalty_earned,
    get_royalty_pending,
    get_royalty_paid,
    get_book_pub_date
]

# %%
llm_with_tools = llm.bind_tools(tools)

# %%
def start_graph(state: State) -> State:
    user_message = HumanMessage(content=(state["user_input"]))
    return {"messages": [user_message]}

# %%
def get_user_intent(state: State) -> Literal["faq", "query", "complaint"]:
    intent = state["intent"]
    return intent

# %%
def answer_query(state: State) -> State:

    book_id = state["book_id"]

    sys_msg = SystemMessage(
        content=(
            "You are a helpful assistant for BookLeaf Publishing. "
            f"You are assisting the author for book ID: {book_id}. "
            "Use the available tools to retrieve book-specific information."
        )
    )
    
    llm_response = llm_with_tools.invoke(
        [sys_msg] + state["messages"]
    )

    return {"messages": [llm_response]}

# %%
import logging

logger = logging.getLogger("author_agent")

logger.setLevel(logging.INFO)

handler = logging.StreamHandler()
formatter = logging.Formatter(
    "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

handler.setFormatter(formatter)

logger.addHandler(handler)

# %%
def register_complaint(state: State) -> State:
    book_id = state["book_id"]
    query = state["user_input"]

    # # This block is failing to write to database, logging for now
    # with sqlite3.connect("db.sqlite3", timeout=30.0) as conn:
    #     cursor = conn.cursor()
    #     cursor.execute("INSERT INTO author_ticket (query, status) VALUES (?, ?)", (query, 'pr'))
    #     conn.commit()
    #     print("Ticket successfully registered!")
    logger.warning(
        "Complaint received complaint=%s",
        state["user_input"]
    )
    
    response = AIMessage(
        content=(
            "Sorry about that. "
            "Your complaint has been registered and will be reviewed."
        )
    )
    return {"messages": [response]}

# %% [markdown]
# ### Answer only if relevant document exists

# %%
def answer_faq(state: State) -> State:

    query = state["user_input"]
    book_id = state["book_id"]

    search_result = similarity_search(query)

    context = search_result["context"]
    distance = search_result["distance"]

    if distance >= 0.8:
        response_context = (
            "The knowledge base does not contain enough "
            "information to confidently answer this question."
        )

    else:
        response_context = context

    INFO_PROMPT = f"""Return an appropriate answer in markdown syntax for user query.
    """
    prompt = INFO_PROMPT

    prompt += (
        f"\nQuery: {query}"
        f"\nResponse: {response_context}"
    )

    llm_response = llm.invoke(prompt)

    return {"messages": [AIMessage(content=llm_response.content)]}

# %%
def build_graph():
    from langgraph.prebuilt import (
        tools_condition,
        ToolNode,
    )
    builder = StateGraph(State)

    builder.add_node("start_graph", start_graph)
    builder.add_node("answer_faq", answer_faq)
    builder.add_node("answer_query", answer_query)
    builder.add_node("register_complaint", register_complaint)
    builder.add_node("tools", ToolNode(tools))

    builder.add_edge(START, "start_graph")

    # Intent routing
    builder.add_conditional_edges(
        "start_graph",
        get_user_intent,
        {"faq": "answer_faq",
         "query": "answer_query",
         "complaint": "register_complaint"}
    )

    # Tool routing
    builder.add_conditional_edges(
        "answer_query",
        tools_condition,
    )
    builder.add_edge(
        "tools",
        "answer_query"
    )

    react_graph = builder.compile(
        checkpointer=checkpointer
    )

    return react_graph

# %%
graph = build_graph()

# %%
graph

# %%
state = {
    "book_id": 70,
    "user_input": "What is your ISBN policy?",
    "intent": "faq"
}
config = {
    "configurable": {
        "thread_id": "105"
    }
}

# %%
result = graph.invoke(state, config=config)

# %%
result["messages"][-1].content
# Out:
# '```markdown\n# ISBN Policy\n\n- Every book published through BookLeaf receives a unique ISBN assigned by BookLeaf.\n- ISBNs are registered under BookLeaf’s publisher imprint. If an author wants an ISBN under their own imprint, they need to obtain it independently.\n- If an author reports an ISBN error (duplicate, wrong book linked), it is treated as a high-priority issue and escalated to the production team.\n```'

# %%
s = {
    "book_id": 70,
    "user_input": "Show me my pending royalty",
    "intent": "query"
}
config = {
    "configurable": {
        "thread_id": "103"
    }
}

# %%
result = graph.invoke(s, config=config)

# %%
result["messages"][-1].content
# Out:
# 'Your pending royalty for the book is $2,464.'

# %%
s = {
    "book_id": 70,
    "user_input": "I found the place very untidy, not coming back again!",
    "intent": "complaint"
    
}
config = {
    "configurable": {
        "thread_id": "104"
    }
}

# %%
result = graph.invoke(s, config=config)
# Out:
# 2026-09-18 12:40:51,412 - author_agent - WARNING - Complaint received complaint=I found the place very untidy, not coming back again!

# %%
result["messages"][-1].content
# Out:
# 'Sorry about that. Your complaint has been registered and will be reviewed.'

# %% [markdown]
# ## Evaluations
